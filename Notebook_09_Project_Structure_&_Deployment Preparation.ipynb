# %% [markdown]
# # ❤️ AI-Powered Heart Disease Prediction System
#
# ## Notebook-09
#
# ### Project Structure & Deployment Preparation
#
# In this notebook, we will organize the project into a professional folder structure before building the Streamlit application.

# %% [markdown]
# Heart_Disease_Prediction/
#
# │
#
# ├── data/
# │     heart.csv
# │
# ├── notebooks/
# │     01_EDA.ipynb
# │     02_Data_Preprocessing.ipynb
# │     03_Feature_Engineering.ipynb
# │     04_Model_Building.ipynb
# │     05_Model_Comparison.ipynb
# │     06_Model_Validation.ipynb
# │     07_Hyperparameter_Tuning.ipynb
# │     08_Final_Model.ipynb
# │
# ├── model/
# │     heart_disease_pipeline.pkl
# │
# ├── app/
# │     app.py
# │
# ├── reports/
# │     Project_Report.pdf
# │
# ├── docs/
# │     README.md
# │     OBJECTIVES.md
# │     PROJECT_FLOW.md
# │     INSTALLATION.md
# │     INTERVIEW_QA.md
# │
# ├── requirements.txt
# │
# └── LICENSE

# %% [markdown]
# ### Advantages
#
# - Easy to maintain
# - Easy deployment
# - Professional GitHub Repository
# - Industry standard organization
# - Better interview presentation

# %%
import os

import shutil
