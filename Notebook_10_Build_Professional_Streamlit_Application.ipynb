# %% [markdown]
# # ❤️ AI-Powered Heart Disease Prediction System
#
# ## Notebook-10
#
# ### Professional Streamlit Application Development
#
# Objective
#
# Build a professional web application for heart disease prediction using the trained machine learning pipeline.
#
# Features
#
# • Application Configuration
# • Load Trained Pipeline
# • User Input Form
# • Prediction Engine
# • Risk Analysis
# • Confidence Score
# • Medical Recommendation
# • Footer

# %%
import streamlit as st
import pandas as pd
import joblib
import numpy as np

# %%
pipeline = joblib.load("heart_disease_pipeline.pkl")

print("✅ Pipeline Loaded Successfully")
